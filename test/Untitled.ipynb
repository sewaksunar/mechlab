# %%
from mechlab.interactive import stress_state_widget

stress_state_widget()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mechlab.interactive import stress_state_widget
#       3 stress_state_widget()
#
# ModuleNotFoundError: No module named 'mechlab'
